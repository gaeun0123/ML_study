# %% [markdown]
# ### 와인을 분류해보자

# %% [markdown]
# 평균을 0으로 표준편차를 1로

# %%
import pandas as pd

red_wine = pd.read_csv('../data/winequality-red.csv', sep=';')
white_wine = pd.read_csv("../data/winequality-white.csv", sep=';')
# Out:
# /tmp/ipykernel_3765/4183824076.py:1: DeprecationWarning:
#
#
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
white_wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# ### 두 데이터를 합쳐보자.
# **컬럼이 같기 때문에, 색을 구분해야하니 임의로 색 컬럼 추가**

# %%
red_wine['color'] = 1.
white_wine['color'] = 0.

wine = pd.concat([red_wine, white_wine])
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 710.6 KB

# %%
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9])

# %% [markdown]
# ### 히스토그램을 그려보자

# %%
# !pip install plotly_express
# Out:
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 33.5 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy>=1.11 in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from plotly_express) (1.26.3)
# Collecting patsy>=0.5
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 KB 55.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.20.0 in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from plotly_express) (2.2.0)
# Collecting plotly>=4.1.0
#   Downloading plotly-5.18.0-py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 63.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy>=0.18 in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from plotly_express) (1.12.0)
# Requirement already satisfied: pytz>=2020.1 in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from pandas>=0.20.0->plotly_express) (2023.4)
# Requirement already satisfied: six in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from patsy>=0.5->plotly_express) (1.16.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging in /home/addinedu/venv/opencv/lib/python3.10/site-packages (from plotly>=4.1.0->plotly_express) (23.2)
# Installing collected packages: tenacity, patsy, plotly, statsmodels, plotly_express
# Successfully installed patsy-0.5.6 plotly-5.18.0 plotly_express-0.4.1 statsmodels-0.14.1 tenacity-8.2.3

# %%
import plotly.express as px

fig = px.histogram(wine, x="quality")
fig.show()

# %%
fig = px.histogram(wine, x="quality", color="color")
fig.show()
# Out:
# /home/addinedu/venv/opencv/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.

# %%
X = wine.drop(['color'], axis=1)
y = wine['color']

# %%
from sklearn.model_selection import train_test_split
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=13)

np.unique(y_train, return_counts=True)
# Out:
# (array([0., 1.]), array([3913, 1284]))

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Histogram(x=X_train['quality'], name='Train'))
fig.add_trace(go.Histogram(x=X_test['quality'], name='Test'))

fig.update_layout(barmode='overlay')
fig.update_traces(opacity=0.75)
fig.show()

# %%
from sklearn.tree import DecisionTreeClassifier

wine_tree = DecisionTreeClassifier(max_depth=2, random_state=13)
wine_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=13)

# %%
from sklearn.metrics import accuracy_score

y_pred_tr = wine_tree.predict(X_train)
y_pred_test = wine_tree.predict(X_test)

print('Train Acc : ', accuracy_score(y_train, y_pred_tr))
print('Test Acc : ', accuracy_score(y_test, y_pred_test))
# Out:
# Train Acc :  0.9553588608812776
# Test Acc :  0.9569230769230769

# %%
fig = go.Figure()

fig.add_trace(go.Box(y=X['fixed acidity'], name='fixed acidity'))
fig.add_trace(go.Box(y=X['chlorides'], name=''))

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

MMS = MinMaxScaler()
SS = StandardScaler()

SS.fit(X)
MMS.fit(X)

X_ss = SS.transform(X)
X_mms = MMS.transform(X)

# %%
X_ss_pd = pd.DataFrame(X_ss, columns=X.columns)
X_mms_pd = pd.DataFrame(X_mms, columns=X.columns)

# %% [markdown]
# MinMaxScaler란 최대 최소값을 1과 0으로 강제로 맞추는 것

# %%
import matplotlib.pyplot as plt
from sklearn import tree

fig = plt.figure(figsize=(15, 8))
# '_' -> 이 다음에 안써도 되는 변수
# return 반환값을 받을 때
_ = tree.plot_tree(wine_tree,
                   feature_names = ['length', 'width'],
                   class_names=list(y),
                   filled=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 7
#       4 fig = plt.figure(figsize=(15, 8))
#       5 # '_' -> 이 다음에 안써도 되는 변수
#       6 # return 반환값을 받을 때
# ----> 7 _ = tree.plot_tree(wine_tree,
#       8                    feature_names = ['length', 'width'],
#       9                    class_names=list(y),
#      10                    filled=True)
#
# File ~/venv/opencv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/venv/opencv/lib/python3.10/site-packages/sklearn/tree/_export.py:211, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     196 check_is_fitted(decision_tree)
#     198 exporter = _MPLTreeExporter(
#     199     max_depth=max_depth,
#     200     feature_names=feature_names,
#    (...)
#     209     fontsize=fontsize,
#     210 )
# --> 211 return exporter.export(decision_tree, ax=ax)
#
# File ~/venv/opencv/lib/python3.10/site-packages/sklearn/tree/_export.py:644, in _MPLTreeExporter.export(self, decision_tree, ax)
#     642 ax.clear()
#     643 ax.set_axis_off()
# --> 644 my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     645 draw_tree = buchheim(my_tree)
#     647 # important to make sure we're still
#     648 # inside the axis after drawing the box
#     649 # this makes sense because the width of a box
#     650 # is about the same as the distance between boxes
#
# File ~/venv/opencv/lib/python3.10/site-packages/sklearn/tree/_export.py:620, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     617 def _make_tree(self, node_id, et, criterion, depth=0):
#     618     # traverses _tree.Tree recursively, builds intermediate
#     619     # "_reingold_tilford.Tree" object
# --> 620     name = self.node_to_str(et, node_id, criterion=criterion)
#     621     if et.children_left[node_id] != _tree.TREE_LEAF and (
#     622         self.max_depth is None or depth <= self.max_depth
#     623     ):
#     624         children = [
#     625             self._make_tree(
#     626                 et.children_left[node_id], et, criterion, depth=depth + 1
#    (...)
#     630             ),
#     631         ]
#
# File ~/venv/opencv/lib/python3.10/site-packages/sklearn/tree/_export.py:311, in _BaseTreeExporter.node_to_str(self, tree, node_id, criterion)
#     308 if tree.children_left[node_id] != _tree.TREE_LEAF:
#     309     # Always write node decision criteria, except for leaves
#     310     if self.feature_names is not None:
# --> 311         feature = self.feature_names[tree.feature[node_id]]
#     312     else:
#     313         feature = "x%s%s%s" % (
#     314             characters[1],
#     315             tree.feature[node_id],
#     316             characters[2],
#     317         )
#
# IndexError: list index out of range

# %% [markdown]
# ### 이진 분류

# %%
5-6등급은 크고
나머지는 작았다
-> 데이터 불균형
그니까 quality를 이진화 할 것

# %%
taste라는 기준을 가진 컬럼 추가

# %%
wine['taste'] = [1. if grade>5 else 0. for grade in wine['quality']]
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   float64
#  13  taste                 6497 non-null   float64
# dtypes: float64(13), int64(1)
# memory usage: 761.4 KB

# %%
X = wine.drop(['taste', 'quality'], axis=1)
y = wine['taste']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state = 13)

wine_tree = DecisionTreeClassifier(max_depth=2, random_state=13)
wine_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=13)

# %%
y_pred_tr = wine_tree.predict(X_train)
y_pred_test = wine_tree.predict(X_test)

# %%
print('Train Acc : ', accuracy_score(y_train, y_pred_tr))
print('Test Acc : ', accuracy_score(y_test, y_pred_test))
# Out:
# Train Acc :  0.7294593034442948
# Test Acc :  0.7161538461538461

# %%
import matplotlib.pyplot as plt
from sklearn import tree

fig = plt.figure(figsize=(15, 8))
# '_' -> 이 다음에 안써도 되는 변수
# return 반환값을 받을 때
_ = tree.plot_tree(wine_tree,
                   feature_names = X_train.columns,
                   class_names=['SOSO', 'GOOD'],
                   rounded=True,
                   filled=True)
